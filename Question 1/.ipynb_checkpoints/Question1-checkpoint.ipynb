# %% [markdown]
# # Question 1

# %% [markdown]
# ### Description:
#
# Is there a positive correlation  between the number of infants who are fully formula fed and the total dollar value of the rebates received by the WIC agency for each state?

# %%
# Run this code cell to import relevant libraries

import numpy as np
import pandas as pd
import seaborn as sns

# %%
# Import data sets here

data = pd.read_csv("../US_Public_Food_Assitance/est13_16us/est13us.csv")
data.head()
# Out:
#   Geographic Information   Unnamed: 1     Unnamed: 2  \
# 0        State FIPS Code  Postal Code           Name
# 1                     00           US  United States
# 2                     01           AL        Alabama
# 3                     02           AK         Alaska
# 4                     04           AZ        Arizona
#
#                      All Ages          Unnamed: 4          Unnamed: 5  \
# 0  Poverty Estimate, All Ages  90% CI Lower Bound  90% CI Upper Bound
# 1                    48810868            48554692            49067044
# 2                      889091              873141              905041
# 3                       72643               69056               76230
# 4                     1206948             1184107             1229789
#
#                   Unnamed: 6          Unnamed: 7          Unnamed: 8  \
# 0  Poverty Percent, All Ages  90% CI Lower Bound  90% CI Upper Bound
# 1                       15.8                15.7                15.9
# 2                       18.9                18.6                19.2
# 3                       10.1                 9.6                10.6
# 4                       18.6                18.2                  19
#
#                      Age 0-17  ...         Unnamed: 20  \
# 0  Poverty Estimate, Age 0-17  ...  90% CI Upper Bound
# 1                    16086960  ...                  21
# 2                      300649  ...                26.6
# 3                       25030  ...                13.8
# 4                      422435  ...                  26
#
#    Median Household Income         Unnamed: 22         Unnamed: 23  \
# 0  Median Household Income  90% CI Lower Bound  90% CI Upper Bound
# 1                    52250               52185               52315
# 2                    42882               42260               43504
# 3                    70058               68425               71691
# 4                    48504               47932               49076
#
#                      Age 0-4         Unnamed: 25         Unnamed: 26  \
# 0  Poverty Estimate, Age 0-4  90% CI Lower Bound  90% CI Upper Bound
# 1                    4811689             4759374             4864004
# 2                      92126               87734               96518
# 3                       8148                7208                9088
# 4                     122889              117153              128625
#
#                 Unnamed: 27         Unnamed: 28         Unnamed: 29
# 0  Poverty Percent, Age 0-4  90% CI Lower Bound  90% CI Upper Bound
# 1                      24.8                24.5                25.1
# 2                      31.6                30.1                33.1
# 3                      14.9                13.2                16.6
# 4                      29.1                27.7                30.5
#
# [5 rows x 30 columns]
